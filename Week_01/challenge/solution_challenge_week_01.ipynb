# %% [markdown]
# # Solution: Challenge Week 01

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# matplotlib.pyplot style
plt.style.use('dark_background')

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Define settings for graphics
# 
# plt.style.use('dark_background')

# Get current working directory
print(os.getcwd())
# Out:
# c:\Users\drito\Documents\SP\scientific_programming\Week_01\challenge

# %% [markdown]
# ## Random numbers

# %%
# Generate 10,000 random numbers between 0 and 100
data = np.random.normal(50, 20, 10000)

# %% [markdown]
# ## Quartiles

# %%
# Lower quartile (25%), median (50%) and upper quartile (75%)
np.percentile(data, [0.25, 0.50, 0.75])
# Out:
# array([-4.10785215, -0.63444185,  1.83124689])

# %% [markdown]
# ## Histogram

# %%
# Plot histogram with 50 bins and green color
plt.figure(figsize=(7,5))
plt.hist(data, bins=50, color='red')

# Add title and labels
plt.title("Histogram of 10,000 randomly generated numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(linestyle='-', linewidth=0.15)

# Show the plot
plt.show()

# %% [markdown]
# ## Boxplot

# %%
# Create boxplot
plt.figure(figsize=(7,1.2))
plt.ticklabel_format(style='plain')
sns.boxplot(x=data, color="yellow")

plt.title("Boxplot of randomly generated numbers")
plt.xlabel("Value")
# Out:
# Text(0.5, 0, 'Value')

# %%
number = 10
print(type(number))  # Output: <class 'int'>
# Out:
# <class 'int'>

# %%
price = 9.99
print(type(price))  # Output: <class 'float'>
# Out:
# <class 'float'>

# %%
is_active = True
print(type(is_active))  # Output: <class 'bool'>
# Out:
# <class 'bool'>

# %%
message = "Hello, World!"
print(type(message))  # Output: <class 'str'>
# Out:
# <class 'str'>
